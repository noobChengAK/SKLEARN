# %%
import numpy as np
import pandas as pd
import os

# %%
#csvFilePath = 'C:\\Users\\Tang\\Documents\\GitHub\\SKLEARN\\y3project\\opp_operation_data\\all.csv'
#csvFilePath = 'C:\\Users\\14761\\Documents\\GitHub\\SKLEARN\\y3project\\opp_operation_data\\all.csv'
csvFilePath = '/home/n34851zc/GitRepos/Y3/SKLEARN/y3project/opp_operation_data/all.csv'

# %%
df = pd.read_csv(csvFilePath,header = None)
df.head()
# Out:
#        0                                               1    2     3  4  \
# 0  20137  test_category_labeling_highlight_fordham_aaaaa  121  3905  0
# 1  20324  test_category_labeling_highlight_fordham_aaaaa  121  3905  1
# 2  20325  test_category_labeling_highlight_fordham_aaaaa  121  3905  1
# 3  20326  test_category_labeling_highlight_fordham_aaaaa  121  3905  2
# 4  20327  test_category_labeling_highlight_fordham_aaaaa  121  3905  3
#
#                             5  \
# 0                       Other
# 1  First Party Collection/Use
# 2  First Party Collection/Use
# 3              Data Retention
# 4  First Party Collection/Use
#
#                                                    6              7  \
# 0  {"Other Type": {"selectedText": "Sci-News.com ...  Not specified
# 1  {"Collection Mode": {"selectedText": "nformati...  Not specified
# 2  {"Collection Mode": {"selectedText": "nformati...  Not specified
# 3  {"Personal Information Type": {"selectedText":...  Not specified
# ...

# %%
df.tail(50)
# Out:
#            0                                       1    2     3   4  \
# 23030   7473  test_category_labeling_highlight_upitt  103  3696  38
# 23031  13986  test_category_labeling_highlight_upitt  123  3696  38
# 23032  13987  test_category_labeling_highlight_upitt  123  3696  38
# 23033  13988  test_category_labeling_highlight_upitt  123  3696  38
# 23034   4416  test_category_labeling_highlight_upitt   95  3696  39
# 23035   7474  test_category_labeling_highlight_upitt  103  3696  39
# 23036  13989  test_category_labeling_highlight_upitt  123  3696  39
# 23037   4417  test_category_labeling_highlight_upitt   95  3696  40
# 23038   7475  test_category_labeling_highlight_upitt  103  3696  40
# 23039  13990  test_category_labeling_highlight_upitt  123  3696  40
# 23040   5975        test_category_labeling_highlight   88  3722   0
# 23041   5982        test_category_labeling_highlight   88  3722   0
# 23042   6749        test_category_labeling_highlight   82  3722   0
# ...

# %% [markdown]
# # operation to category

# %%
df.iloc[:,1]
# Out:
# 0        test_category_labeling_highlight_fordham_aaaaa
# 1        test_category_labeling_highlight_fordham_aaaaa
# 2        test_category_labeling_highlight_fordham_aaaaa
# 3        test_category_labeling_highlight_fordham_aaaaa
# 4        test_category_labeling_highlight_fordham_aaaaa
#                               ...
# 23075                  test_category_labeling_highlight
# 23076                  test_category_labeling_highlight
# 23077                  test_category_labeling_highlight
# 23078                  test_category_labeling_highlight
# 23079                  test_category_labeling_highlight
# Name: 1, Length: 23080, dtype: object

# %%
#remove the first 33 lines to df{1}
df[1] = df[1].map(lambda x: str(x)[33:])

# %%
df[1].head(10)
# Out:
# 0    fordham_aaaaa
# 1    fordham_aaaaa
# 2    fordham_aaaaa
# 3    fordham_aaaaa
# 4    fordham_aaaaa
# 5    fordham_aaaaa
# 6    fordham_aaaaa
# 7    fordham_aaaaa
# 8    fordham_aaaaa
# 9    fordham_aaaaa
# Name: 1, dtype: object

# %%
df.columns = ['0','1','2','3','4','5','6','7','8']

# %%
df.head(20)
# Out:
#         0              1    2     3   4                                     5  \
# 0   20137  fordham_aaaaa  121  3905   0                                 Other
# 1   20324  fordham_aaaaa  121  3905   1            First Party Collection/Use
# 2   20325  fordham_aaaaa  121  3905   1            First Party Collection/Use
# 3   20326  fordham_aaaaa  121  3905   2                        Data Retention
# 4   20327  fordham_aaaaa  121  3905   3            First Party Collection/Use
# 5   20328  fordham_aaaaa  121  3905   3            First Party Collection/Use
# 6   20329  fordham_aaaaa  121  3905   3            First Party Collection/Use
# 7   20330  fordham_aaaaa  121  3905   3            First Party Collection/Use
# 8   20331  fordham_aaaaa  121  3905   4  International and Specific Audiences
# 9   20332  fordham_aaaaa  121  3905   4                                 Other
# 10  20333  fordham_aaaaa  121  3905   5            First Party Collection/Use
# ...

# %% [markdown]
# ## remove the other columns, keep the category and the segments

# %%
df1 = df.iloc[:,[5,6]]

# %%
df_with_category_and_segments = df1

#rename the columns 5 and 6
df_with_category_and_segments.rename(columns = {'5': 'Category','6':'Segements'},inplace = True)
# df_with_category_and_segments = df1
df_with_category_and_segments
# df2 = df_with_category_and_segments
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                          Category  \
# 0                           Other
# 1      First Party Collection/Use
# 2      First Party Collection/Use
# 3                  Data Retention
# 4      First Party Collection/Use
# ...                           ...
# 23075                       Other
# 23076                       Other
# 23077                       Other
# 23078                       Other
# 23079                       Other
#
#                                                Segements
# 0      {"Other Type": {"selectedText": "Sci-News.com ...
# 1      {"Collection Mode": {"selectedText": "nformati...
# ...

# %%
SaveDestination = '/home/n34851zc/GitRepos/Y3/SKLEARN/y3project/opp_operation_data'
SaveFileName = 'two_columns.csv'
df_with_category_and_segments.to_csv(SaveDestination + '/' + SaveFileName,encoding = "utf_8_sig",index = False)

# %% [markdown]
# ## Use nlp method to pick the information from segments column

# %%
#because the segemnt column is about Json format,so we import json to pandas
import json

# %%
#df_with_category_and_segments.read_json()
